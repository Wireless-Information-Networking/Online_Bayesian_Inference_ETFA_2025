# %% [markdown]
# # Model for ETFA 2025

# %% [markdown]
# ## Imports

# %%
import os

import pvlib
from pvlib.location import Location
from pvlib.temperature import TEMPERATURE_MODEL_PARAMETERS
from pvlib.pvsystem import PVSystem
from pvlib.modelchain import ModelChain

import torch
from torch import nn
import torch.nn.functional as F

import pyro
import pyro.distributions as dist
from pyro.nn import PyroSample
from pyro.infer.autoguide import AutoNormal
from pyro.nn import PyroModule
from pyro.infer import SVI, Trace_ELBO
from pyro.infer import Predictive

import pandas as pd
from pandas import DataFrame

import numpy as np

import matplotlib.pyplot as plt

import seaborn as sns

import scienceplots

from IPython.display import clear_output

# %% [markdown]
# ## Debug activation

# %%
DEBUG = True

# %% [markdown]
# ## System definition

# %%
# Define the location of the PV system
latitude = 41.499779
longitude = 2.111753
timezone = 'Europe/Madrid'
altitude = 133
location_name = 'UAB'
location = Location(latitude=latitude, longitude=longitude,
                    tz=timezone, altitude=altitude, name=location_name)

# Define temperature model parameters
temperature_parameters = TEMPERATURE_MODEL_PARAMETERS['sapm']['open_rack_glass_glass']


# Define the PV system (specialy module)
sandia_modules = pvlib.pvsystem.retrieve_sam('SandiaMod')
CEC_inverters = pvlib.pvsystem.retrieve_sam('CECInverter')

module = sandia_modules['Canadian_Solar_CS5P_220M___2009_']
inverter = CEC_inverters['ABB__MICRO_0_25_I_OUTD_US_208__208V_']

if DEBUG:
    print(f'Module for testing: \n{module}')


module_efficiency = module['Vmpo'] * module['Impo'] / (1000*module['Area'])
module_area = module['Area']

if DEBUG:
    print(f'Efficiency of the module (datasheet): {module_efficiency*100} %')

azimuth_south_centered = 0
system = PVSystem(surface_tilt=30, surface_azimuth=(180-azimuth_south_centered),
                  module_parameters=module, inverter_parameters=inverter,
                  temperature_model_parameters=temperature_parameters)

if DEBUG:
    print(f'System for testing: \n{system}')


# Generate the model chain
modelchain = ModelChain(system, location)
if DEBUG and True:
    print(f'Model chain for testing: \n{modelchain}')


# Define the time period for the simulation
start_time = '2024-01-01'
end_time = '2027-12-31 23:00:00'
times = pd.date_range(start=start_time, end=end_time,
                      freq='1h', tz=location.tz)

# Generate the weather data
weather = location.get_clearsky(times)
irradiance_W = weather['ghi'] 

if DEBUG:
    print(f'Weather data for testing: \n{weather}')
    n_days = (weather.index[-1] - weather.index[0]).days + 1
    width_per_day = 2  # inches per day
    fig_width = max(12, n_days * width_per_day)  # minimum width for small datasets
    weather.plot(figsize=(fig_width, 5))
    plt.show()

# %% [markdown]
# ## Functions for plotting

# %% [markdown]
# ### Config

# %%
plt.style.use(["science", "no-latex"])
plt.rcParams.update({
    "font.size": 28,           # Base font size for all text in the plot.
    "axes.titlesize": 12,      # Title size for axes.
    "axes.labelsize": 12,      # Axis labels size.
    "xtick.labelsize": 22,     # X-axis tick labels size.
    "ytick.labelsize": 22,     # Y-axis tick labels size.
    "legend.fontsize": 100,     # Legend font size.
    "figure.titlesize": 32,    # Overall figure title size.
})
sns.set_theme(style="whitegrid", context="paper") # Set seaborn theme for additional aesthetics and context.

# %% [markdown]
# ### Functions

# %%
def plot3days(power_data: DataFrame) -> None:
    """Plot the power output for 3 sample days, 
    including confidence intervals and ground truth.

    Args:
        power_data (DataFrame): Hourly power output data 
            must contain the following columns:
            - Index: Datetime index with hourly frequency.
            - 'power_mean': Predicted power output.
            - 'power_upper': Upper bound of the confidence interval.
            - 'power_lower': Lower bound of the confidence interval.
            - 'gth_power': Ground truth power output.
            - 'ref_power': Reference power output.
    """

    # 1) Get first, middle, and last days
    middle_day_number = len(power_data) // (2*24)
    last_day_number = len(power_data) // 24

    first_day = power_data.iloc[0:24]
    middle_day = power_data.iloc[24*middle_day_number:24*(middle_day_number+1)]
    last_day = power_data.iloc[-24:]
    
    three_days = pd.concat([first_day, middle_day, last_day])

    # 2) Extract each series
    pred_power = three_days['power_mean']
    pred_upper = three_days['power_upper']
    pred_lower = three_days['power_lower']
    gth_power = three_days['gth_power']
    ref_power = three_days['ref_power']

    # 3) Create new index: Day 1-00 ... Day 3-23
    new_index = [f"Day {d+1}-{h:02d}" for d in range(3) for h in range(24)]
    min_len = min(len(new_index), len(three_days))
    new_index = new_index[:min_len]
    
    pred_power = pred_power.iloc[:min_len]
    pred_upper = pred_upper.iloc[:min_len]
    pred_lower = pred_lower.iloc[:min_len]
    gth_power = gth_power.iloc[:min_len]
    ref_power = ref_power.iloc[:min_len]

    pred_power.index = new_index
    pred_upper.index = new_index
    pred_lower.index = new_index
    gth_power.index = new_index
    ref_power.index = new_index

    # 4) Plot
    plt.figure(figsize=(12, 5))
    plt.plot(pred_power.index, pred_power.values, label='Predicted Power', color='tab:blue', linewidth=2)
    plt.fill_between(pred_power.index, pred_lower.values, pred_upper.values, color='tab:blue', alpha=0.3, label='90\\% Confidence Interval')
    plt.plot(gth_power.index, gth_power.values, label='Ground Truth', color='tab:green', linewidth=2, linestyle='--')
    plt.plot(ref_power.index, ref_power.values, label='Reference', color='tab:red', linewidth=2, linestyle=':')

    # Set fewer x-ticks: only show 0, 12, 23 for each day
    xticks = [0, 12, 23, 24+12, 24+23, 48+12, 48+23]
    xtick_labels = [
        "D1-00H", "D1-12H", "D1-23H",
        f"D{middle_day_number+1}-12H", f"D{middle_day_number+1}-23H",
        f"D{last_day_number+1}-12H", f"D{last_day_number+1}-23H"
    ]
    plt.xticks(xticks, xtick_labels, rotation=0)

    # Add thick vertical lines to separate days
    for sep in [24, 48]:
        plt.axvline(sep - 0.5, color='black', linewidth=3, alpha=0.5)

    plt.title("Hourly Power Output: Model Prediction vs Ground Truth (3 Sample Days)", fontsize=20)
    plt.xlabel("Day-Hour", fontsize=16)
    plt.ylabel("Power (W)", fontsize=16)
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.grid(True, axis='y')
    plt.legend(fontsize=12, frameon=True, facecolor='white', edgecolor='black')
    plt.tight_layout()
    plt.show()

def plotOutputEvolution(power_data: DataFrame) -> None:
    """Plot the daily power output evolution, 
    including confidence intervals and ground truth.

    Args:
        power_data (DataFrame): Hourly power output data
            must contain the following columns:
            - Index: Datetime index with hourly frequency.
            - 'power_mean': Predicted power output.
            - 'power_upper': Upper bound of the confidence interval.
            - 'power_lower': Lower bound of the confidence interval.
            - 'gth_power': Ground truth power output.
            - 'ref_power': Reference power output.
    """
    # 1) Prepare the data
    # Agregate the power output data to daily frequency
    power_data_daily = power_data.resample('D').sum()

    # 2) configure the plot
    n_days = (power_data_daily.index[-1] - power_data_daily.index[0]).days + 1
    width_per_day = 0.05  # inches per day
    fig_width = max(10, n_days * width_per_day)  # minimum width for small datasets
    plt.figure(figsize=(fig_width, 9))

    plt.rc('text', usetex=True)
    plt.rc('font', family='serif')

    # 3) Extract each series
    pred_power = power_data_daily['power_mean']
    pred_upper = power_data_daily['power_upper']
    pred_lower = power_data_daily['power_lower']
    gth_power = power_data_daily['gth_power']
    ref_power = power_data_daily['ref_power']

    plt.plot(power_data_daily.index, pred_power, label="Predicted Power", color='tab:blue', linewidth=2)
    plt.fill_between(power_data_daily.index, pred_lower, pred_upper, color='tab:blue', alpha=0.3, label='90\\% Confidence Interval')
    plt.plot(power_data_daily.index, gth_power, label="Ground Truth", color='tab:green', linewidth=2, linestyle='--')
    plt.plot(power_data_daily.index, ref_power, label="Reference", color='tab:red', linewidth=2, linestyle=':')

    # 4) Plot
    plt.title("Daily Power Output: Model Prediction vs Ground Truth", fontsize=24)
    plt.xlabel("Day-Hour", fontsize=18)
    plt.xticks(fontsize=14)
    plt.ylabel("Power (W)", fontsize=18)
    plt.yticks(fontsize=14)
    plt.grid(True, axis='y')
    plt.legend(fontsize=12, frameon=True, facecolor='white', edgecolor='black')
    plt.show()

def plotEfficiencyEvolution(efficiency_data: DataFrame) -> None:
    """Plot the daily efficiency evolution,
    including confidence intervals and ground truth.

    Args:
        efficiency_data (DataFrame): Hourly efficiency data
            must contain the following columns:
            - Index: Datetime index with hourly frequency.
            - 'efficiency_mean': Predicted efficiency.
            - 'efficiency_upper': Upper bound of the confidence interval.
            - 'efficiency_lower': Lower bound of the confidence interval.
            - 'gth_efficiency': Ground truth efficiency.
            - 'ref_efficiency': Reference efficiency.
    """

    # 1) configure the plot
    n_days = (efficiency_data.index[-1] - efficiency_data.index[0]).days + 1
    width_per_day = 0.05  # inches per day
    fig_width = max(10, n_days * width_per_day)  # minimum width for small datasets
    plt.figure(figsize=(fig_width, 9))

    plt.rc('text', usetex=True)
    plt.rc('font', family='serif')

    # 3) Extract each series
    pred_efficiency = efficiency_data['efficiency_mean']
    efficiency_upper = efficiency_data['efficiency_upper']
    efficiency_lower = efficiency_data['efficiency_lower']
    gth_efficiency = efficiency_data['gth_efficiency']
    ref_efficiency = efficiency_data['ref_efficiency']

    # 4) Plot
    plt.plot(efficiency_data.index, pred_efficiency * 100, label="Predicted Efficiency", color='tab:blue', linewidth=2)
    plt.fill_between(efficiency_data.index, efficiency_lower * 100, efficiency_upper * 100, color='tab:blue', alpha=0.3, label='90\\% Confidence Interval')
    plt.plot(efficiency_data.index, gth_efficiency * 100, label="Ground Truth", color='tab:green', alpha=0.6, linewidth=2, linestyle='--')
    plt.plot(efficiency_data.index, ref_efficiency * 100, label="Reference", color='tab:red', linewidth=2, linestyle=':')
    plt.title("Daily Efficiency: Model Estimation vs Ground Truth", fontsize=24)
    plt.xlabel("Day-Hour", fontsize=18)
    plt.xticks(fontsize=14)
    plt.ylabel("Efficiency (\\%)", fontsize=18)
    plt.yticks(fontsize=14)
    plt.grid(True, axis='y')
    plt.legend(fontsize=12, frameon=True, facecolor='white', edgecolor='black')
    plt.show()

# %% [markdown]
# ## Dataframes

# %%
power_data = pd.DataFrame({
    'power_mean': [],
    'power_upper': [], 
    'power_lower': [],
    'gth_power': [],
    'ref_power': []
})

efficiency_data = pd.DataFrame({
    'efficiency_mean': [],
    'efficiency_upper': [],
    'efficiency_lower': [],
    'gth_efficiency': [],
    'ref_efficiency': []
})

# %% [markdown]
# ## Ground truth (pvlib)

# %%
modelchain.run_model(weather=weather)
power_data['gth_power'] = modelchain.results.dc['p_mp']

x_data = torch.tensor((weather['ghi'].values * module_area), dtype=torch.float32)
y_data = torch.tensor(power_data['gth_power'], dtype=torch.float32)
x_data_daily = pd.Series(x_data.numpy(), index=weather.index).resample('D').sum()
y_data_daily = pd.Series(y_data.numpy(), index=power_data.index).resample('D').sum()
eff_data_daily = pd.Series(y_data_daily / x_data_daily, index=x_data_daily.index)

efficiency_data['gth_efficiency'] = eff_data_daily


if DEBUG:
    plotOutputEvolution(power_data)
    plotEfficiencyEvolution(efficiency_data)

# %% [markdown]
# ## Model for Reference

# %% [markdown]
# P = Area · eff · solar_power
#
# No training involved

# %%
power_data['ref_power'] = module['Area'] * module_efficiency * weather['ghi']
efficiency_data['ref_efficiency'] = module_efficiency

if DEBUG:
    plotOutputEvolution(power_data)
    plotEfficiencyEvolution(efficiency_data)

# %% [markdown]
# ## Model: Online Batesian Inference

# %% [markdown]
# ### 1) Define data

# %%
# Done already in Ground Truth

# %% [markdown]
# ### 2) Define model

# %%
def model(x_data, gth_power=None):
    efficiency = pyro.sample("efficiency", dist.Normal(module_efficiency, 1.))
    sigma = pyro.sample("sigma", dist.Uniform(0., 10.))

    mean = efficiency * x_data

    mean = F.relu(mean)  # Ensure mean is non-negative

    with pyro.plate("data_day", len(x_data)):
        return pyro.sample("power_obs", dist.Normal(mean, sigma), obs=gth_power)

pyro.render_model(model, model_args=(x_data, y_data), render_distributions=True, render_params=True)

# %% [markdown]
# ### 3) Define guide

# %%
# Using AutoNormal for automatic guide generation
guide = AutoNormal(model,
                   init_loc_fn=pyro.infer.autoguide.initialization.init_to_value(values={"efficiency": torch.tensor([[module_efficiency]])}),
                   init_scale=0.1)
pyro.render_model(guide, model_args=(x_data, y_data), render_distributions=True, render_params=True)

# %% [markdown]
# ### 4) Define optimization parameters

# %%
adam = pyro.optim.Adam({"lr": 0.001})
svi = SVI(model, guide, adam, loss=Trace_ELBO())
predictive = Predictive(model, guide=guide, num_samples=1000,
                        return_sites=("_RETURN",))

# %% [markdown]
# ### 5) Training

# %%
# List for storing results
power_mean_list = [None] * len(power_data)
power_upper_list = [None] * len(power_data)
power_lower_list = [None] * len(x_data)

efficiency_mean_list = [None] * len(efficiency_data)
efficiency_upper_list = [None] * len(efficiency_data)
efficiency_lower_list = [None] * len(efficiency_data)

efficiency_mean_day = [None] * 24
efficiency_upper_day = [None] * 24
efficiency_lower_day = [None] * 24

# guide initialization with a 0 
svi.step(x_data[0].unsqueeze(0), gth_power=y_data[0].unsqueeze(0))

# get n_days from the data
n_days = (power_data.index[-1] - power_data.index[0]).days + 1

for day in range(n_days):
    # 1) Predict the power output for this day
    for i in range(24):
        x = x_data[day * 24 + i].unsqueeze(0)
        y = y_data[day * 24 + i].unsqueeze(0)
        
        # Predictive sampling
        samples = predictive(x)
        
        # Extract the predicted power output
        power_mean = samples["_RETURN"].mean()
        power_upper = samples["_RETURN"].quantile(0.95)
        power_lower = samples["_RETURN"].quantile(0.05)

        efficiency_mean = guide.quantiles([0.5])["efficiency"].detach()
        efficiency_upper = guide.quantiles([0.95])["efficiency"].detach()
        efficiency_lower = guide.quantiles([0.05])["efficiency"].detach()

        # Store the results
        power_mean_list[day * 24 + i] = power_mean.item()
        power_upper_list[day * 24 + i] = power_upper.item()
        power_lower_list[day * 24 + i] = power_lower.item()

        print(f"index: {i} out of {len(efficiency_mean_day)}")
        efficiency_mean_day[i] = efficiency_mean.item()
        efficiency_upper_day[i] = efficiency_upper.item()
        efficiency_lower_day[i] = efficiency_lower.item()

        if i == 23:
            efficiency_mean_list[day] = np.mean(efficiency_mean_day)
            efficiency_upper_list[day] = np.mean(efficiency_upper_day)
            efficiency_lower_list[day] = np.mean(efficiency_lower_day)

            efficiency_mean_day = [None] * 24
            efficiency_upper_day = [None] * 24
            efficiency_lower_day = [None] * 24


        if DEBUG:
            print(f"Iteration: {day * 24 + i} / {n_days * 24}")
            print(f"Power output: {power_lower} - {power_mean} - {power_upper} GTH: {y}")
            print(f"Efficiency: {efficiency_lower.item()} - {efficiency_mean.item()} - {efficiency_upper.item()} GTH: {y/x}")


    # 2) Step hourly
    for i in range(24):
        x = x_data[day * 24 + i].unsqueeze(0)
        y = y_data[day * 24 + i].unsqueeze(0)

        svi.step(x, gth_power=y)

    # 3) Plot the results
    if DEBUG:
        clear_output(wait=True)

        # Fill the DataFrame with the results
        power_data['power_mean'] = pd.Series(power_mean_list, index=power_data.index).fillna(0)
        power_data['power_upper'] = pd.Series(power_upper_list, index=power_data.index).fillna(0)
        power_data['power_lower'] = pd.Series(power_lower_list, index=power_data.index).fillna(0)
        efficiency_data['efficiency_mean'] = pd.Series(efficiency_mean_list, index=efficiency_data.index)
        efficiency_data['efficiency_upper'] = pd.Series(efficiency_upper_list, index=efficiency_data.index) 
        efficiency_data['efficiency_lower'] = pd.Series(efficiency_lower_list, index=efficiency_data.index)

        plotEfficiencyEvolution(efficiency_data)
        plotOutputEvolution(power_data)

# %% [markdown]
# ### 6) Ploting

# %%
plot3days(power_data)
plotOutputEvolution(power_data)
plotEfficiencyEvolution(efficiency_data)

# Aggregate x_data by day and plot daily sum
x_data_daily = pd.Series(x_data.numpy(), index=weather.index).resample('D').sum()

plt.figure(figsize=(12, 5))
plt.plot(x_data_daily.index, x_data_daily.values, label='Daily Irradiance * A (Wh)', color='tab:orange', linewidth=2)
plt.title("Daily Irradiance * Area of the Module", fontsize=24)
plt.xlabel("Date", fontsize=18)
plt.xticks(fontsize=14)
plt.ylabel("Irradiance * Area (Wh)", fontsize=18)
plt.yticks(fontsize=14)
plt.grid(True, axis='y')
plt.legend(fontsize=12, frameon=True, facecolor='white', edgecolor='black')
plt.tight_layout()
plt.show()

# Aggregate y_data by day and plot daily sum
y_data_daily = pd.Series(y_data.numpy(), index=power_data.index).resample('D').sum()
plt.figure(figsize=(12, 5))
plt.plot(y_data_daily.index, y_data_daily.values, label='Daily Power Output (Wh)', color='tab:green', linewidth=2)
plt.title("Daily Power Output (Ground Truth)", fontsize=24)
plt.xlabel("Date", fontsize=18)
plt.xticks(fontsize=14)
plt.ylabel("Power Output (Wh)", fontsize=18)
plt.yticks(fontsize=14)
plt.grid(True, axis='y')
plt.legend(fontsize=12, frameon=True, facecolor='white', edgecolor='black')
plt.tight_layout()
plt.show()

# Plot daily efficiency against gth
eff_data_daily = pd.Series(y_data_daily / x_data_daily, index=x_data_daily.index)
plt.figure(figsize=(12, 5))
plt.plot(eff_data_daily.index, eff_data_daily.values * 100, label='Y/X', color='tab:blue', linewidth=2)
plt.plot(eff_data_daily.index, efficiency_data['gth_efficiency'].resample('D').mean() * 100, label='GTH', color='tab:orange', linewidth=2)
plt.title("Daily Efficiency (Ground Truth)", fontsize=24)
plt.xlabel("Date", fontsize=18)
plt.xticks(fontsize=14)
plt.ylabel("Efficiency (\\%)", fontsize=18)
plt.yticks(fontsize=14)
plt.grid(True, axis='y')
plt.legend(fontsize=12, frameon=True, facecolor='white', edgecolor='black')
plt.tight_layout()
plt.show()
